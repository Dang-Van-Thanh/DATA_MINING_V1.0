# %% [markdown]
# # Supervised Learning

# %%
# 04. Supervised Modeling
Dự đoán khả năng đăng ký term deposit

# %% [markdown]
# # Train/Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_transformed, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %% [markdown]
# # Train models

# %%
from src.models.supervised import SupervisedTrainer

trainer = SupervisedTrainer({
    "logistic_regression": {"enabled": True, "max_iter": 1000, "class_weight": "balanced"},
    "random_forest": {"enabled": True, "n_estimators": 300, "class_weight": "balanced"},
    "xgboost": {"enabled": False}
})

results = trainer.train_eval(X_train, X_test, y_train, y_test)
results

# %% [markdown]
# # So sánh kết quả

# %%
pd.DataFrame([
    {"model": k, "f1": v["f1"], "pr_auc": v["pr_auc"]}
    for k,v in results.items()
])

# %% [markdown]
# Kết luận: RF thường outperform LogReg.
